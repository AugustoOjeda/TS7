# %% [markdown]
# <img src="./logo_UNSAM.jpg" align="right" width="150" />
#
# # Análisis y procesamiento de señales
# ## Augusto Ojeda-Matias Carbajal TS7: Transformada Z y su respuesta en frecuencia

# %% [markdown]
# ### Introducción teórica

# %% [markdown]
# La transformada Z es una herramienta fundamental en el analisis y diseños de sistemas digitales, ya que permite representar señales y sistemas discretos en el dominio complejo, Es analoga a la transformada de Laplace en sistemas continuos, pero adaptada a secuencias discretas en el tiempo. Para una secuencia x[n], la transformada Z se define como:
# $$X(z)=\sum_{k=-\infty}^{\infty}x[k]re^{-j \omega_0 n} $$
# Para avanzar con esta explicacion teorica vamos a definir $z=-j \omega_0 n$ Esta representación permite estudiar las propiedades de estabilidad y causalidad de los sistemas ya que los polos y ceros de T(z) determinan el comportamiento del sistema. En general lo que se busca son series convergentes es decir series dondes los polos se encuentran en el semiplano izquierdo o que se acumulen en el 0. El valor r me permite barrer todo el plano complejo y genera periodicidad al tener un dominio circular, ahora bien no todo r genera convergencia y me permite analizar tanto estados transitarios como los estados permanentes.

# %% [markdown]
# La mayoria de los sistemas pueden expresarse como una razon de dos polinomios
# $$T(z)=\frac{N(z)}{D(z)}=\frac{\sum_{k=0}^{M}b_kz^{-k}}{\sum_{k=0}^{M}a_kz^{-k}}$$
# Los ceros son los valores de z que anulan N(z), mientras que los polos son los que anulan D(z). La ubicación de estos polos y ceros en el plano Z define el comportamiento del sistema en frecuencia y su estabilidad.La respuesta en frecuencia de un sistea discreto se obtiene al evaluar T(z) sobre el circulo unitario del plano complejo $$T(e^{-j \omega})=H(z)|_{z=e^{-j \omega}}$$

# %% [markdown]
# Esta evaluacion relaciona directamente la transformada Z con la DTFT ya que describe como el sistema modifica la amplitud y la fase de cada componente de frecuencia de la señal de entrada. El modulo indicla la ganancia en magnitud mientras que su argumento el desfase introducido por el sistema.

# %% [markdown]
# ### Análisis, desarollo y Discusión

# %% [markdown]
# Para analizar la transformada Z y su respuesta en frecuencia$$ $$1) se buscara  hallar la funcion transferencia $$T(z)=\frac{Y(z)}{X(z)}$$ 2)Se buscara calcular la respuesta en frecuencia de modulo y fase$$ $$
# 3) Simular y validar la respuesta en frecuencia de todos los sistemas con numpy.

# %% [markdown]
# Para el punto 1 y 2 se realizo a mano los ejercicios a mano obteniendo lo siguiente:

# %% [markdown]
# <img src="./modulo_fase_y1.jpg" align="right" width="1500" />

# %% [markdown]
# <img src="./modulo_fase_y2.jpg" align="right" width="1500" />

# %% [markdown]
# <img src="./modulo_fase_y3.jpg" align="right" width="1500" />

# %% [markdown]
# <img src="./modulo_fase_y4.jpg" align="right" width="1500" />

# %% [markdown]
# Para poder comprar los resultados con los obtenidos mas adelante con los obtenidos con spyder, se grafico los resultados de modulo y fase para cada uno de los puntos obteniendo lo siguiente

# %% [markdown]
# <img src="./Moduloejercicoa.jpg" align="right" width="1500" />
#
# **Imagen [1]:** imagen del modulo del ejercicio a).

# %% [markdown]
# <img src="./Moduloejerciciob.jpg" align="right" width="1500" />
#
# **Imagen [2]:** imagen del modulo del ejercicio b).

# %% [markdown]
# <img src="./Moduloejercicioc.jpg" align="right" width="1500" />
#
# **Imagen [3]:** imagen del modulo del ejercicio c).

# %% [markdown]
# <img src="./Moduloejerciciod.jpg" align="right" width="1500" />
#
# **Imagen [4]:** imagen del modulo del ejercicio d).

# %% [markdown]
# <img src="./fasea.jpg" align="right" width="1500" />
#
# **Imagen [5]:** imagen de la fase del ejercicio a)

# %% [markdown]
# <img src="./faseb.jpg" align="right" width="1500" />
#
# **Imagen [6]:** imagen de la fase del ejercicio b)

# %% [markdown]
# <img src="./fasec.jpg" align="right" width="1500" />
#
# **Imagen [7]:** imagen de la fase del ejercicio c)

# %% [markdown]
# <img src="./fased.jpg" align="right" width="1500" />
#
# **Imagen [8]:** imagen de la fase del ejercicio d)

# %% [markdown]
# Lo importante que se puede observar es que de la $imagen [7]$ a la $[8]$ todas las fases obtenidas son lineales como nos predecia la teoria

# %% [markdown]
# 3) A partir de los resultados teóricos, se buscó representarlos gráficamente en Spyder con el objetivo de verificar si coincidían con los obtenidos mediante la simulación computacional.
# Para ello, se utilizó la función freqz de la librería Signal de SciPy. Esta función permite al usuario definir cuatro parámetros principales: los coeficientes $b_k$ y $a_k$, junto con las opciones de frecuencia. En este caso, se adoptó $a_0=1$ y se consideraron nulos los demás coeficientes $a_k$ (para k>0), motivo por el cual se introdujo simplemente a=1. En cambio, los valores de $b_k$ se asignaron de acuerdo con los obtenidos a partir de las ecuaciones teóricas.

# %% [markdown]
# Finalmente, se fijó una frecuencia de muestreo arbitraria de fs=1000 Hz, con el propósito de expresar los resultados directamente en unidades de frecuencia (Hz) en lugar de radianes por muestra (rad/muestra), evitando así la necesidad de un reescalado posterior. Para utilizar el codigo se definieron los siguientes vectores y cte

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as sig

#Coeficientes
ba=[1,1,1,1]
bb=[1,1,1,1,1]
bc=[1,-1]
bd=[1,-1]

#cte 
fs=1000 #Hz

# %%
#freqz para cada caso
wa,ha=sig.freqz(b=ba,a=1,whole=False,fs=fs) 
wb,hb=sig.freqz(b=bb,a=1,whole=False, fs=fs)
wc,hc=sig.freqz(b=bc,a=1,whole=False, fs=fs)
wd,hd=sig.freqz(b=bd,a=1,whole=False, fs=fs)

# %% [markdown]
# Al utilizar freqz obtenemos dos salidas, las cual en generar se representan como w y h, en este caso se dio una señalizacion a cada salida dependiendo del ejercicio donde w equivale a las frecuencias en las que se calculó h, expresadas en las mismas unidades que la frecuencia de muestreo fs y h equivale a la respuesta en frecuencia, representada mediante números complejos (contiene tanto la magnitud como la fase del sistema). Con esto en mente se calculo el modulo y la fase de las siguiente manera:

# %%
#maginitud y fase
maga=np.abs(ha) #Modulo T(e^jΩ)
fasea=np.unwrap(np.angle(ha)) #Fase T(e^jΩ) (radianes)
magb=np.abs(hb) #Modulo T(e^jΩ)
faseb=np.unwrap(np.angle(hb)) #Fase T(e^jΩ) (radianes) 
magc=np.abs(hc) #Modulo T(e^jΩ)
fasec=np.unwrap(np.angle(hc)) #Fase T(e^jΩ) (radianes)
magd=np.abs(hd) #Modulo T(e^jΩ)
fased=np.unwrap(np.angle(hd)) #Fase T(e^jΩ) (radianes)

# %%
plt.figure()
plt.plot(wa, maga)
plt.title('Imagen [9]:Respuesta en frecuencia |t(e^{jΩ})|, para el ejercicio a')
plt.ylabel('Modulo |t(e^{jΩ})|')
plt.xlabel('frecuencia (Hz)')
# Out:
# Text(0.5, 0, 'frecuencia (Hz)')

# %% [markdown]
# Al comparar la imagen $[1]$ con la imagen $[9]$ podemos ver que el modulo que buscabamos obtener se represento tal y cual lo esperabamos, la diferencia principal es que este se grafico hasta nyquist tal y como nuestro codigo dijo que iba a hacer asi que podemos afirmar que lo obtenido es correcto.

# %%
plt.figure()
plt.plot(wa, fasea)
plt.title('Imagen [10]:Respuesta en frecuencia de la fase para el ejercicio a')
plt.xlabel('Frecuencia [Hz]')
plt.ylabel('Fase [rad]')
# Out:
# Text(0, 0.5, 'Fase [rad]')

# %% [markdown]
# Ahora bien, al comparar la imagen $[10]$ con la imagen $[5]$, podemos ver que hay una subida inesperada en lo que parece $fs/4$, aunque la documentacion no nos indica que esto puede ocurrir al buscar informacion, muchas veces estos codigos pueden general subidas inesperadas en ceros de la funcion explicando por que puede ocurrir esto, como veremos mas adelante esto se vuelve a repetir para otras fases, a pesar de esto podemos hablar de que tenemos una buena linealidad

# %%
plt.figure()
plt.plot(wb, magb)
plt.title('Imagen [11]:Respuesta en frecuencia |t(e^{jΩ})|, para el ejercicio b')
plt.ylabel('Modulo |t(e^{jΩ})|')
plt.xlabel('frecuencia (Hz)')
# Out:
# Text(0.5, 0, 'frecuencia (Hz)')

# %% [markdown]
# Nuevamente podemos ver que los modulos coinciden tanto el teorico calculado a mano como el obtenido con los codigos de spyder esto, lo que podemos afirmar es que si quisieramos utilizar estas funciones transferencias como filtros, tanto el punto $a)$ y el punto $b)$ pueden funcionar como filtros pasa bajos.

# %%
plt.figure()
plt.plot(wb, faseb)
plt.title('Imagen [12]:Respuesta en frecuencia de la fase para el ejercicio a')
plt.xlabel('Frecuencia [Hz]')
plt.ylabel('Fase [rad]')
# Out:
# Text(0, 0.5, 'Fase [rad]')

# %% [markdown]
# Podemos ver nuevamente estos "escalones", los cuales se pueden nuevamente relacionar con ceros teoricos

# %%
plt.figure()
plt.plot(wc, magc)
plt.title('Imagen [13]:Respuesta en frecuencia |t(e^{jΩ})|, para el ejercicio c')
plt.ylabel('Modulo |t(e^{jΩ})|')
plt.xlabel('frecuencia (Hz)')
# Out:
# Text(0.5, 0, 'frecuencia (Hz)')

# %% [markdown]
# En la imagen $[13]$ se vuelve a cumplir simultaneidad hasta nyquist, nos podemos quedar tranquilo por que luego de nyquist tenemos sampleo pudiendo afirmar que obtuvimos el mismo grafico

# %%
plt.figure()
plt.plot(wc, fasec)
plt.title('Imagen [14]:Respuesta en frecuencia de la fase para el ejercicio c')
plt.xlabel('Frecuencia [Hz]')
plt.ylabel('Fase [rad]')
# Out:
# Text(0, 0.5, 'Fase [rad]')

# %% [markdown]
# Podemos ver en la imagen $[14]$ que ahora si tenemos una fase lineal con puntos acumulados en el 0 los cuales podemos afirmar que son por los ceros de la funcion, esto podira confirmar nuestra teoria anterior.

# %%
plt.figure()
plt.plot(wd, magd)
plt.title('Imagen [15]:Respuesta en frecuencia |t(e^{jΩ})|, para el ejercicio d')
plt.ylabel('Modulo |t(e^{jΩ})|')
plt.xlabel('frecuencia (Hz)')
# Out:
# Text(0.5, 0, 'frecuencia (Hz)')

# %%
plt.figure()
plt.plot(wd, fased)
plt.title('Imagen [16]:Respuesta en frecuencia de la fase para el ejercicio d')
plt.xlabel('Frecuencia [Hz]')
plt.ylabel('Fase [rad]')
# Out:
# Text(0, 0.5, 'Fase [rad]')

# %% [markdown]
# Podemos ver lo mismo tanto en la imagen $[14]$ como en la $[16]$ pudiendo confirmar lo que veniamos teorizando.

# %% [markdown]
# ### Conclusiones

# %% [markdown]
# En conclusión, el análisis realizado permitió comprobar la relación entre la Transformada Z y la respuesta en frecuencia de los sistemas discretos. A través del estudio de polos y ceros en el plano Z se pudo interpretar el comportamiento del sistema, su estabilidad y la forma en que modifica la magnitud y la fase de las señales de entrada. La evaluación sobre el círculo unitario permitió vincular directamente la Transformada Z con la DTFT, confirmando así los conceptos teóricos desarrollados en el informe.

# %% [markdown]
# ### Autoevaluación del aprendizaje

# %% [markdown]
# Indicar si se utilizó IA:
# Sí, usé chatGPT.
# En caso afirmativo, indicar una opción o varias:
# Escritura: Me ayudó a mejorar la coherencia y la cohesión de mis textos, además de corregir faltas de ortografía, ya que en este editor de texto no cuento con las líneas rojas que me indiquen si escribí algo mal. Generalmente lo utilizo con ese propósito.
